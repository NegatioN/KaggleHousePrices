# %%
import keras
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 970 (CNMeM is disabled, cuDNN 5103)
# /home/joakim/anaconda2/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Lambda
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', None)

# %%
def get_train_val(path, val_size):
    dataframe = pd.read_csv(path)
    return train_test_split(dataframe, test_size=val_size)

# %%
path = "data/"

# %%
train, valid = get_train_val(path + "train.csv", 0.2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 35 to 822
# Data columns (total 81 columns):
# Id               1168 non-null int64
# MSSubClass       1168 non-null int64
# MSZoning         1168 non-null object
# LotFrontage      947 non-null float64
# LotArea          1168 non-null int64
# Street           1168 non-null object
# Alley            74 non-null object
# LotShape         1168 non-null object
# LandContour      1168 non-null object
# Utilities        1168 non-null object
# LotConfig        1168 non-null object
# LandSlope        1168 non-null object
# Neighborhood     1168 non-null object
# Condition1       1168 non-null object
# Condition2       1168 non-null object
# BldgType         1168 non-null object
# HouseStyle       1168 non-null object
# OverallQual      1168 non-null int64
# OverallCond      1168 non-null int64
# YearBuilt        1168 non-null int64
# YearRemodAdd     1168 non-null int64
# RoofStyle        1168 non-null object
# ...

# %%
train.head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 35      36          60       RL        108.0    13418   Pave   NaN      Reg
# 1064  1065          20       RL          NaN    11000   Pave   NaN      IR1
# 1123  1124          20       RL         50.0     9405   Pave   NaN      Reg
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 35           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1064         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 1123         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 15           Lvl    AllPub    Corner       Gtl      BrkSide       Norm
# 19           Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # Data cleaning?
# Looks like we have to do a shitload of data-cleaning to get some of these NaNs and string-defined fields over to something useful.
#
# Make all string-fields to_categorical somehow?
#
# Is it parhaps easier to map all NaNs to 0 in a categorical system? While still preserving the data.

# %%
print("We have {} Not-NaN MiscFeatures".format(len(train['MiscFeature'].dropna())))
print("We have {} Not-NaN PoolQC".format(len(train['PoolQC'].dropna())))
print("We have {} Not-NaN Alley".format(len(train['Alley'].dropna())))
print("We have {} Not-NaN FireplaceQu".format(len(train['FireplaceQu'].dropna())))
# Out:
# We have 39 Not-NaN MiscFeatures
# We have 5 Not-NaN PoolQC
# We have 74 Not-NaN Alley
# We have 624 Not-NaN FireplaceQu

# %% [markdown]
# Can we use 1D CNN's to infer the patterns in important features here?
